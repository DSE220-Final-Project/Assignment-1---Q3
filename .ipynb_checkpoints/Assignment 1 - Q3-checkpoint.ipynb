# %% [markdown]
# ## IRI Data - Q3

# %% [markdown]
# Problem #3
#
# The IRI data is set available on the AWS instance.  Several additional documents describing the data set and pointing to additional Bibliography are made available (including the white paper: Bronnenberg, Bart J., Kruger, Michael W, and Mela, Carl F. The IRI Marketing Dataset.). <br />
# <br />
# Getting to know this data set is time well spent as it will be very applicable towards the Fina project.  The data set is of medium size and complexity – however understanding the data and how file/folders/datasets related to each other will be of crucial importance for creating an appropriate training data set.  <br />
# <br />
# The data set has been purchase by UCSD, it is only for internal use and comes with restrictions.  Please read and follow the NDA specified at the very end of the “IRI_database_technical_appendix” document provided with the data set. <br />
# <br />
# I order to answer the questions below – document and describe what kind of data preparation and cleaning techniques did you have to apply?  What kinds of anomalies and missing data did you encounter?  Document how what assumption you made and how you approach the issues.
# 1. What are the most popular item(s) for a chosen product/category?<br />
# 2. How does the popularity of an item change with the cost associated with it for a chosen year?<br />
# 3. How is the popularity affected over the years? <br />
# <br />
# ### Extra credit: (Not done yet)
# Apply K-nearest neighbor algorithms to a chose subset of data for a specific set of products/categories.

# %%
# %load_ext sql
# Out:
# /Users/phesami/anaconda/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /Users/phesami/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %%sql postgresql://sharknado:sharknado@sharknado-dse.ceg3hdkdq8l0.us-east-1.rds.amazonaws.com/sharknado
# select * from test
# Out:
# 3 rows affected.
# [(u'alex',), (u'john',), (u'david',)]

# %%
import pandas as pd
import numpy as np

# %%
## Get data for Salty snacks
# %cd /Users/phesami/Documents/DSE/DSE220_Final_Project/IRI_Data/
# Out:
# /Users/phesami/Documents/DSE/DSE220_Final_Project/IRI_Data

# %% [markdown]
# #### Get data

# %% [markdown]
# ##### Store level weekly data

# %%
# Considering only 3 years for the analysis
store_data = {}
yrs = ['1']
# yrs = ['01','02']
# yrs = ['11']
import os
for i in yrs:
    tmp = 'store_yr_'+str(i)
    filepath = '/Users/phesami/Documents/DSE/DSE220_Final_Project/IRI_Data'+'/Year'+str(i)+'/External/saltsnck/'
    filename = os.listdir(filepath)
    file1 = filter(lambda filename: filename.startswith("saltsnck_drug"),filename)
    store_data["year"+str(i)+'drug'] = pd.read_fwf(filepath+'/'+file1[0])
    store_data["year"+str(i)+'drug']['yr'] = str(i)
    store_data["year"+str(i)+'drug']['store_type'] = 'drug'
    file2 = filter(lambda filename: filename.startswith("saltsnck_g"),filename)
    store_data["year"+str(i)+'groc'] = pd.read_fwf(filepath+'/'+file2[0])
    store_data["year"+str(i)+'groc']['yr'] = str(i)
    store_data["year"+str(i)+'groc']['store_type'] = 'groc'

# %%
store_data.keys()
# Out:
# ['year1drug', 'year1groc']

# %%
store_data
# Out:
# {'year1drug':          IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F  D  PR yr  \
#  0         664497  1114   0   1  41633   2154      3     2.97  NONE  0   0  1
#  1         664497  1114   0   2  41633    145      6    13.14  NONE  0   0  1
#  2         664497  1114   0   1  41633   2119      3     2.97  NONE  0   0  1
#  3         664497  1114   0   2  41633    135      3     6.57  NONE  0   0  1
#  1092960  8000583  1165   0   3  41262  27131      1     1.49  NONE  0   0  1
#  1092961  8000583  1165   0   1  28400    553      3     2.97  NONE  0   0  1
#  1092962  8000583  1165   0   3  28400   1422      1     1.99  NONE  0   0  1
#  1092963  8000583  1165   0   1  16000  28320      1     1.19     B  0   1  1
#  1092964  8000583  1165   0   1  16000  28370      4     4.76     B  2   1  1
#  1092965  8000583  1165   0   1  28400   9160      1     0.59  NONE  0   0  1
#  1092966  8000583  1165   0   3  28400   1864      2     4.58  NONE  0   0  1
#  1092967  8000583  1165   0   2  28400    869      1     0.99  NONE  0   0  1
#  1092968  8000583  1165   0   1  16000  15940      4     4.76     B  2   1  1
#  1092969  8000583  1165   0   1  16000  12530      1     1.19  NONE  0   1  1
#  1092970  8000583  1165   0   1  16000  12250      3     1.77  NONE  0   0  1
#  1092971  8000583  1165   0   2  24100  30053      1     1.99  NONE  0   0  1
#  1092972  8000583  1165   0   2  24100  12260      1     2.59  NONE  0   0  1
#  1092973  8000583  1165   0   4  41262  27299      1     0.99  NONE  0   0  1
#  1092974  8000583  1165   0   1  28400   1266      1     2.29  NONE  0   0  1
#
#          store_type
#  0             drug
#  1             drug
#  2             drug
#  3             drug
#  4             drug
#  5             drug
#  6             drug
#  7             drug
#  8             drug
#  9             drug
#  10            drug
#  11            drug
#  12            drug
#  13            drug
#  14            drug
#  15            drug
#  16            drug
#  17            drug
#  18            drug
#  19            drug
#  20            drug
#  21            drug
#  22            drug
#  23            drug
#  24            drug
#  25            drug
#  26            drug
#  27            drug
#  28            drug
#  29            drug
#  ...            ...
#  1092945       drug
#  1092946       drug
#  1092947       drug
#  1092948       drug
#  1092949       drug
#  1092950       drug
#  1092951       drug
#  1092952       drug
#  1092953       drug
#  1092954       drug
#  1092955       drug
#  1092956       drug
#  1092957       drug
#  1092958       drug
#  1092959       drug
#  1092960       drug
#  1092961       drug
#  1092962       drug
#  1092963       drug
#  1092964       drug
#  1092965       drug
#  1092966       drug
#  1092967       drug
#  1092968       drug
#  1092969       drug
#  1092970       drug
#  1092971       drug
#  1092972       drug
#  1092973       drug
#  1092974       drug
#
#  [1092975 rows x 13 columns],
#  'year1groc':           IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F  D  PR yr  \
#  0          253422  1114   0   1  78271   1008      3     9.87  NONE  0   0  1
#  1          253422  1114   0   1  78271    301      3     2.97  NONE  0   0  1
#  2          253422  1114   0   1  78271    300      5     4.95  NONE  0   0  1
#  3          253422  1114   0   1  78271    304      1     0.99  NONE  0   0  1
#  4          253422  1114   0   1  78271   2060      8    15.92  NONE  0   0  1
#  5          253422  1114   0   1  78271    615      2     3.98  NONE  0   0  1
#  6          253422  1114   0   1  78271    601      3     5.97  NONE  0   0  1
#  7          253422  1114   0   1  78271    302      5     4.95  NONE  0   0  1
#  8          253422  1114   0   1  78271   2062      2     3.98  NONE  0   0  1
#  9          253422  1114   0   1  78271    306      6     5.94  NONE  0   0  1
#  16728626   653776  1165   0   1  41500  21012      1     1.83  NONE  0   0  1
#  16728627   653776  1165   0   2  15665  60100      2     4.38  NONE  0   0  1
#  16728628   653776  1165   7   1  20495  39347      7    12.53  NONE  0   0  1
#  16728629   653776  1165   7   1  20495  39313     10    17.90  NONE  0   0  1
#  16728630   653776  1165   7   1  20495  39321     10    17.90  NONE  0   0  1
#  16728631   653776  1165   7   1  20495  90200     33    62.04  NONE  1   1  1
#  16728632   653776  1165   7   1  20495  90300     20    37.60  NONE  1   1  1
#  16728633   653776  1165  88   5  99998  58066      3     4.11  NONE  0   0  1
#  16728634   653776  1165  88   5  99998  58068      1     2.88  NONE  0   0  1
#
#           store_type
#  0              groc
#  1              groc
#  2              groc
#  3              groc
#  4              groc
#  5              groc
#  6              groc
#  7              groc
#  8              groc
#  9              groc
#  10             groc
#  11             groc
#  12             groc
#  13             groc
#  14             groc
#  15             groc
#  16             groc
#  17             groc
#  18             groc
#  19             groc
#  20             groc
#  21             groc
#  22             groc
#  23             groc
#  24             groc
#  25             groc
#  26             groc
#  27             groc
#  28             groc
#  29             groc
#  ...             ...
#  16728605       groc
#  16728606       groc
#  16728607       groc
#  16728608       groc
#  16728609       groc
#  16728610       groc
#  16728611       groc
#  16728612       groc
#  16728613       groc
#  16728614       groc
#  16728615       groc
#  16728616       groc
#  16728617       groc
#  16728618       groc
#  16728619       groc
#  16728620       groc
#  16728621       groc
#  16728622       groc
#  16728623       groc
#  16728624       groc
#  16728625       groc
#  16728626       groc
#  16728627       groc
#  16728628       groc
#  16728629       groc
#  16728630       groc
#  16728631       groc
#  16728632       groc
#  16728633       groc
#  16728634       groc
#
#  [16728635 rows x 13 columns]}

# %% [markdown]
# ##### Product attributes
#
# The improved file format, which incorporates further information, is prod_category.xls, 16 There are three sets of files.<br />
# 1. The first set of files are applicable to years 1-6 and are provided in a directory called “parsed stub files”.<br />
# 2. The second set of files are applicable to year 7 and are provided in a directory called “parsed stub files 2007”.<br />
# 3. The third set of files are applicable to years 8-11 are are provided in a directory called “parsed stub files 2008-2011”

# %%
# Get the product category details for the analysis

df1 = pd.ExcelFile('parsed stub files/prod_saltsnck.xls')
prod_cat_1 = df1.parse('Sheet1')

df2 = pd.ExcelFile('parsed stub files 2007/prod_saltsnck.xlsx')
prod_cat_2 = df2.parse('Sheet1')

# We will be using only prod_cat_3 for this analysis
df2 = pd.ExcelFile('parsed stub files 2008-2011/prod11_saltsnck.xlsx')
prod_cat_3 = df2.parse('Sheet1')

# %%
prod_cat_2
# Out:
#                                       L1                             L2  \
# 0      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 1      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 2      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 3      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 4      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 5      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 6      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 7      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 8      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 9      CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 10     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 11     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 12     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 13     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 14     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 15     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 16     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 17     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 18     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 19     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 20     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 21     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 22     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 23     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 24     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 25     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 26     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 27     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 28     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# 29     CATEGORY - SALTY SNACKS                             POTATO CHIPS
# ...                                  ...                            ...
# 17942  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17943  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17944  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17945  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17946  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17947  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17948  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17949  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17950  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17951  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17952  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17953  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17954  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17955  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17956  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17957  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17958  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 17959  CATEGORY - SALTY SNACKS            OTHER SALTED SNACKS (NO NUTS)
# 
# 17958    +PRV * TRDNL BPZCL SNKMX 15OZ      9  88-04-99998-32531  88   4
# 17959    +PRV * TRDNL PBCRC SNKMX 15OZ      9  88-04-99998-32532  88   4
# 17960  +PRV * TRDNL PWCCT SNKMX 8.75OZ      9  88-04-99998-32533  88   4
# 17961     +PRV * TRDNL RBCSP SNKMX 7OZ      9  88-04-99998-32534  88   4
# 17962  +PRV * TRDNL RYPBC SNKMX 8.75OZ      9  88-04-99998-32535  88   4
# 17963           +PRV * VEGMD VTSNC 8OZ      9  88-04-99998-32536  88   4
# 17964         +PRV * VGTBL VGTCH 7.5OZ      9  88-04-99998-32537  88   4
# 17965         +PRV * WHCHD SYCHP 3.5OZ      9  88-04-99998-32538  88   4
# 17966         +PRV * WSABI RGPEA 6.5OZ      9  88-04-99998-32539  88   4
# 17967   +PRV * ZCHDR PCPNB SNKMX 7.5OZ      9  88-04-99998-32540  88   4
# 17968       +PRV * ZSTY ASST SNKMX 8OZ      9  88-04-99998-32541  88   4
# 17969     +PRV * ZSTY CTCHP SNKMX 13OZ      9  88-04-99998-32542  88   4
# 17970     +PRV * ZSTY PTRCC SNKMX 10OZ      9  88-04-99998-32543  88   4
# 17971         +PRV * ZTBBQ SOCRP 3.5OZ      9  88-04-99998-32544  88   4
#
#           ...       ITEM  \
# 0         ...      20210
# 1         ...      20220
# 2         ...      50003
# 3         ...      50004
# 4         ...      50006
# 5         ...          1
# 6         ...          3
# 7         ...          0
# 8         ...          2
# 9         ...       1615
# 10        ...       1418
# 11        ...       1721
# 12        ...       1716
# 13        ...       1216
# 14        ...       1216
# 15        ...       1216
# 16        ...       1211
# 17        ...       1620
# 18        ...       1317
# 19        ...       1317
# 20        ...       1312
# 21        ...       1519
# 22        ...       1822
# 23        ...       1822
# 24        ...       1923
# 25        ...      92842
# 26        ...      92686
# 27        ...       1424
# 28        ...       2032
# 29        ...      61025
# ...       ...        ...
# 17942     ...      32515
# 17943     ...      32516
# 17944     ...      32517
# 17945     ...      32518
# 17946     ...      32519
# 17947     ...      32520
# 17948     ...      32521
# 17949     ...      32522
# 17950     ...      32523
# 17951     ...      32524
# 17952     ...      32525
# 17953     ...      32526
# 17954     ...      32527
# 17955     ...      32528
# 17956     ...      32529
# 17957     ...      32530
# 17958     ...      32531
# 17959     ...      32532
# 17960     ...      32533
# 17961     ...      32534
# 17962     ...      32535
# 17963     ...      32536
# 17964     ...      32537
# 17965     ...      32538
# 17966     ...      32539
# 17967     ...      32540
# 17968     ...      32541
# 17969     ...      32542
# 17970     ...      32543
# 17971     ...      32544
#
#        *STUBSPEC 1431IS                                                         00004    \
# 0              +ENFUG HT PTCHP FLAT         6OZ 0 1 7...
# 1              +ENFUG HT PTCHP WAVY         6OZ 0 1 7...
# 2              +LSBS1 BBQ PTCHP FLAT        7OZ 0 1 7...
# 3              +LSBS1 REG PTCHP FLAT        7OZ 0 1 7...
# 4              +LSBS1 REG PTCHP RPLD        7OZ 0 1 7...
# 5              +ACHC1 BBQ PTCHP FLAT        5OZ 8 1 5...
# 17960          +PRV * TRDNL PWCCT SNKMX  8.75OZ88 4 9...
# 17961          +PRV * TRDNL RBCSP SNKMX     7OZ88 4 9...
# 17962          +PRV * TRDNL RYPBC SNKMX  8.75OZ88 4 9...
# 17963          +PRV * VEGMD VTSNC           8OZ88 4 9...
# 17964          +PRV * VGTBL VGTCH         7.5OZ88 4 9...
# 17965          +PRV * WHCHD SYCHP         3.5OZ88 4 9...
# 17966          +PRV * WSABI RGPEA         6.5OZ88 4 9...
# 17967          +PRV * ZCHDR PCPNB SNKMX   7.5OZ88 4 9...
# 17968          +PRV * ZSTY ASST SNKMX       8OZ88 4 9...
# 17969          +PRV * ZSTY CTCHP SNKMX     13OZ88 4 9...
# 17970          +PRV * ZSTY PTRCC SNKMX     10OZ88 4 9...
# 17971          +PRV * ZTBBQ SOCRP         3.5OZ88 4 9...
#
#        VOL_EQ        PRODUCT TYPE            PACKAGE          FLAVOR/SCENT  \
# 0      0.3750         POTATO CHIP                BAG                   HOT
# 1      0.3750         POTATO CHIP                BAG                   HOT
# 2      0.4375         POTATO CHIP                BAG              BARBECUE
# 3      0.4375         POTATO CHIP                BAG               REGULAR
# 4      0.4375         POTATO CHIP                BAG               REGULAR
# 5      0.3125         POTATO CHIP                BAG              BARBECUE
# 6      0.3125         POTATO CHIP                BAG              JALAPENO
# 7      0.3125         POTATO CHIP                BAG               REGULAR
# 8      0.3125         POTATO CHIP                BAG    SOUR CREAM & CHIVE
# 9      0.6250         POTATO CHIP                BAG              BARBECUE
# 10     0.6250         POTATO CHIP                BAG                  DILL
# 11     0.6250         POTATO CHIP                BAG     GARLIC & PARMESAN
# 12     0.1094         POTATO CHIP                BAG               MISSING
# 13     0.6250         POTATO CHIP                BAG          HOT JALAPENO
# 14     0.6250         POTATO CHIP                BAG          HOT JALAPENO
# 15     0.6250         POTATO CHIP                BAG          HOT JALAPENO
# 16     0.6250         POTATO CHIP                BAG              JALAPENO
# 17     0.6250         POTATO CHIP                BAG  MESQUITE SMOKED BRBQ
# 18     0.6250         POTATO CHIP                BAG              ORIGINAL
# 19     0.6250         POTATO CHIP                BAG              ORIGINAL
# 20     0.6250         POTATO CHIP                BAG               REGULAR
# 21     0.6250         POTATO CHIP                BAG               REGULAR
# 22     0.6250         POTATO CHIP                BAG        SALT & VINEGAR
# 23     0.6250         POTATO CHIP                BAG        SALT & VINEGAR
# 24     0.6250         POTATO CHIP                BAG               MISSING
# 25     0.5000         POTATO CHIP                BAG               REGULAR
# 26     1.0000         POTATO CHIP                BAG               REGULAR
# 27     0.2500         POTATO CHIP                BAG                 SWEET
# 28     0.3125         POTATO CHIP                BAG          SWEET POTATO
# 29     0.4688         POTATO CHIP                BAG               REGULAR
# ...       ...                 ...                ...                   ...
# 17942  0.4375           SNACK MIX                BAG         SWEET & SPICY
# 17943  0.9375           PARTY MIX                BAG           TRADITIONAL
# 17944  0.5313           PARTY MIX                BAG           TRADITIONAL
# 17945  0.5469           PARTY MIX                BAG           TRADITIONAL
# 17946  0.5000           SNACK MIX                BAG           TRADITIONAL
# 17947  0.9375           SNACK MIX                BAG           TRADITIONAL
# 17948  0.9375           SNACK MIX                BAG           TRADITIONAL
# 17949  1.7500           SNACK MIX                BAG           TRADITIONAL
# 17950  1.8750           SNACK MIX  PLASTIC CONTAINER           TRADITIONAL
# 17951  0.4844           SNACK MIX                BAG           TRADITIONAL
# 17952  0.5469           SNACK MIX                BAG           TRADITIONAL
# 17953  0.5469           SNACK MIX                BAG           TRADITIONAL
# 17954  0.5469           SNACK MIX        PLASTIC BAG           TRADITIONAL
# 17955  0.4844           SNACK MIX                BAG           TRADITIONAL
# 17956  0.5469           SNACK MIX                BAG           TRADITIONAL
# 17957  0.4844           SNACK MIX        PLASTIC BAG           TRADITIONAL
# 17958  0.9375           SNACK MIX                BAG           TRADITIONAL
# 17959  0.9375           SNACK MIX                BAG           TRADITIONAL
# 17960  0.5469           SNACK MIX                BAG           TRADITIONAL
# 17961  0.4375           SNACK MIX     RESEALABLE BAG           TRADITIONAL
# 17962  0.5469           SNACK MIX                BAG           TRADITIONAL
# 17963  0.5000     VEGETABLE SNACK                BAG      VEGETABLE MEDLEY
# 17964  0.4688      VEGETABLE CHIP                BAG             VEGETABLE
# 17965  0.2188            SOY CHIP                BAG         WHITE CHEDDAR
# 17966  0.4063  ROASTED GREEN PEAS                BAG                WASABI
# 17967  0.4688           SNACK MIX                BAG         ZESTY CHEDDAR
# 17968  0.5000           SNACK MIX        PLASTIC BAG                 ZESTY
# 17969  0.8125           SNACK MIX                BAG                 ZESTY
# 17970  0.6250           SNACK MIX                BAG                 ZESTY
# 17971  0.2188           SOY CRISP                BAG        ZESTY BARBECUE
#
#       FAT CONTENT COOKING METHOD SALT/SODIUM CONTENT TYPE OF CUT
# 0         MISSING        MISSING             MISSING        FLAT
# 1         MISSING        MISSING             MISSING        WAVY
# 2         MISSING        MISSING             MISSING        FLAT
# 3         MISSING        MISSING             MISSING        FLAT
# 4         MISSING        MISSING             MISSING     RIPPLED
# 5         MISSING  KETTLE COOKED             MISSING        FLAT
# 6         MISSING  KETTLE COOKED             MISSING        FLAT
# 7         MISSING  KETTLE COOKED      LIGHTLY SALTED        FLAT
# 8         MISSING  KETTLE COOKED             MISSING        FLAT
# 9         MISSING        MISSING             MISSING        FLAT
# 10        MISSING        MISSING             MISSING        FLAT
# 11        MISSING        MISSING             MISSING        FLAT
# 12        MISSING        MISSING             MISSING        FLAT
# 13        MISSING  KETTLE COOKED             MISSING        FLAT
# 14        MISSING  KETTLE COOKED             MISSING        FLAT
# 15        MISSING        MISSING             MISSING        FLAT
# 16        MISSING        MISSING             MISSING        FLAT
# 17        MISSING        MISSING             MISSING        FLAT
# 18        MISSING  KETTLE COOKED             MISSING        FLAT
# 19        MISSING        CRUNCHY             MISSING       THICK
# 20        MISSING        MISSING             MISSING        FLAT
# 21        MISSING        MISSING             NO SALT        FLAT
# 22        MISSING  KETTLE COOKED             MISSING        FLAT
# 23        MISSING  KETTLE COOKED             MISSING        FLAT
# 24        MISSING        MISSING             MISSING   THICK CUT
# 25        MISSING  KETTLE COOKED             MISSING        FLAT
# 26        MISSING  KETTLE COOKED             MISSING        FLAT
# 27        MISSING        MISSING             MISSING        FLAT
# 28        MISSING        MISSING             MISSING        FLAT
# 29        MISSING        MISSING             NO SALT        FLAT
# ...           ...            ...                 ...         ...
# 17942     MISSING        MISSING             MISSING     MISSING
# 17943     MISSING        MISSING             MISSING     MISSING
# 17944     MISSING        MISSING             MISSING     MISSING
# 17945     MISSING        MISSING             MISSING     MISSING
# 17946     MISSING        MISSING             MISSING     MISSING
# 17947     MISSING        MISSING             MISSING     MISSING
# 17948     MISSING        MISSING             MISSING     MISSING
# 17949     MISSING        MISSING             MISSING     MISSING
# 17950     MISSING        MISSING             MISSING     MISSING
# 17951     MISSING        MISSING             MISSING     MISSING
# 17952     MISSING        MISSING             MISSING     MISSING
# 17953     MISSING        MISSING             MISSING     MISSING
# 17954     MISSING        MISSING             MISSING     MISSING
# 17955     MISSING        MISSING             MISSING     MISSING
# 17956     MISSING        MISSING             MISSING     MISSING
# 17957     MISSING        MISSING             MISSING     MISSING
# 17958     MISSING        MISSING              SALTED     MISSING
# 17959     MISSING        MISSING             MISSING     MISSING
# 17960     MISSING        MISSING             MISSING     MISSING
# 17961     MISSING        MISSING             MISSING     MISSING
# 17962     MISSING        MISSING             MISSING     MISSING
# 17963     MISSING        MISSING             MISSING     MISSING
# 17964     MISSING        MISSING             MISSING     MISSING
# 17965     MISSING        MISSING             MISSING     MISSING
# 17966     MISSING        MISSING             MISSING     MISSING
# 17967     MISSING        MISSING             MISSING     MISSING
# 17968     MISSING        MISSING             MISSING     MISSING
# 17969     MISSING        MISSING             MISSING     MISSING
# 17970     MISSING        MISSING             MISSING     MISSING
# 17971     MISSING        MISSING             MISSING     MISSING
#
# [17972 rows x 21 columns]

# %% [markdown]
# ##### Q1) What are the most popular item(s) for a chosen product/category?
#
# I looked mostly at the number of units sold in the year 2011 as a proxy for popularity of the product.
#
# REGULAR POTATO CHIP IN A BAG is the most popular item.
#
# Couldn't look into FAT CONTENT, COOKING METHOD, SALT/SODIUM CONTENT or TYPE OF CUT because of missing data.

# %%
# For this we will consider the most recent year 2011.

# Combine data for drugstores and grocery stores
frames = [store_data['year11drug'], store_data['year11groc']]
data_2011 = pd.concat(frames)

# Merge the store data with product category data
data_2011_with_cat = pd.merge(data_2011, prod_cat_3, how='left', on=['ITEM', 'ITEM'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-07c8105c73ca> in <module>()
#       2
#       3 # Combine data for drugstores and grocery stores
# ----> 4 frames = [store_data['year11drug'], store_data['year11groc']]
#       5 data_2011 = pd.concat(frames)
#       6
#
# KeyError: 'year11drug'

# %%
# Get the most popular product 
# Filtered out only required columns as using the entire table was causing the system to crash
temp = data_2011_with_cat[['PRODUCT TYPE','PACKAGE','FLAVOR/SCENT','FAT CONTENT','COOKING METHOD','SALT/SODIUM CONTENT','TYPE OF CUT','UNITS','DOLLARS']]
temp.groupby(['PRODUCT TYPE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                    UNITS       DOLLARS
# PRODUCT TYPE
# POTATO CHIP    233266784  5.272667e+08
# TORTILLA CHIP  121969958  3.131993e+08
# RTE POPCORN    109442905  2.471672e+08
# PRETZEL         56451920  1.321804e+08
# CHEESE SNACK    42998080  8.853130e+07

# %%
# Now that we know that 'Potato Chip' is the most popular product, I wanted to understand if we see any preference in packaging
temp[temp['PRODUCT TYPE']=='POTATO CHIP'].groupby(['PACKAGE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                           UNITS       DOLLARS
# PACKAGE
# BAG                   223955809  5.038678e+08
# BAG IN BOX              3110279  8.451179e+06
# BOX                     2838465  7.095764e+06
# BAG IN BAG               813948  2.321228e+06
# BAG IN BAG INDV WRAP     711263  1.707785e+06

# %%
# Knowing that 'Potato chip' in a bag is the most preferred product, I wanted to see if there is any preference for flavour
temp[(temp['PRODUCT TYPE']=='POTATO CHIP')&(temp['PACKAGE']=='BAG')].groupby(['FLAVOR/SCENT'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                        UNITS       DOLLARS
# FLAVOR/SCENT
# REGULAR             65540217  1.463151e+08
# CLASSIC             22288386  5.115768e+07
# BARBECUE            19855618  4.056266e+07
# ORIGINAL            16790944  4.480575e+07
# SOUR CREAM & ONION  14981454  3.142769e+07

# %% [markdown]
# ##### Q2) How does the popularity of an item change with the cost associated with it for a chosen year?
#
# To understand how popularity of an item changes with cost associated with it, I took the data at the most granular level, SKU-week-store level and calculated the cost per unit. Then calculated the correlation of units and cost.
#
# In this exercise, I found that popularity decreases as the cost associated with the product increases.

# %%
## Get Dollar/Unit at SKU-week-store level
temp_with_dol_per_unit = data_2011_with_cat[['IRI_KEY','WEEK','L9','UNITS','DOLLARS']].copy()
temp_with_dol_per_unit['DOL_PER_UNIT'] = temp_with_dol_per_unit['DOLLARS']/temp_with_dol_per_unit['UNITS']

# %%
temp_with_dol_per_unit[['UNITS','DOL_PER_UNIT']].corr()
# Out:
#                  UNITS  DOL_PER_UNIT
# UNITS         1.000000     -0.141734
# DOL_PER_UNIT -0.141734      1.000000

# %% [markdown]
# ##### Q3) How is the popularity affected over the years?
#
# To understand the popularity of the product over the years, I am going to consider 2 more years of data (2009 and 2010) and see how the top popular items have changed.
#
# From the analysis, we can see that people absolutely love REGULAR - POTATO CHIP BAG. The preferences has been constant in the 3 years 2009,2010 and 2011.

# %%
# Analyse the years 2009 and 2010 to understand yearly trends

## 2010

# For this we will consider the most recent year 2011.

# Combine data for drugstores and grocery stores
frames = [store_data['year10drug'], store_data['year10groc']]
data_2010 = pd.concat(frames)

# %%
# Merge the store data with product category data
data_2010_with_cat = pd.merge(data_2010[['ITEM','UNITS','DOLLARS']], prod_cat_3[['ITEM','PRODUCT TYPE','PACKAGE','FLAVOR/SCENT']], how='left', on=['ITEM', 'ITEM'])

# %%
# Get the most popular product 
# Filtered out only required columns as using the entire table was causing the system to crash
# temp = data_2010_with_cat[['PRODUCT TYPE','PACKAGE','FLAVOR/SCENT','UNITS','DOLLARS']]
temp = data_2010_with_cat.copy()

# %%
temp.groupby(['PRODUCT TYPE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                    UNITS       DOLLARS
# PRODUCT TYPE
# POTATO CHIP    233033671  5.063260e+08
# TORTILLA CHIP  123354325  3.125108e+08
# RTE POPCORN    109378966  2.450784e+08
# PRETZEL         59658918  1.334708e+08
# CHEESE SNACK    41104440  8.129556e+07

# %%
# Now that we know that 'Potato Chip' is the most popular product, I wanted to understand if we see any preference in packaging
temp[temp['PRODUCT TYPE']=='POTATO CHIP'].groupby(['PACKAGE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                           UNITS       DOLLARS
# PACKAGE
# BAG                   223640138  4.833442e+08
# BOX                     3293748  8.335918e+06
# BAG IN BOX              2998029  7.618460e+06
# BAG IN BAG               893960  2.368614e+06
# BAG IN BAG INDV WRAP     718883  1.603734e+06

# %%
# Knowing that 'Potato chip' in a bag is the most preferred product, I wanted to see if there is any preference for flavour
temp[(temp['PRODUCT TYPE']=='POTATO CHIP')&(temp['PACKAGE']=='BAG')].groupby(['FLAVOR/SCENT'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                        UNITS       DOLLARS
# FLAVOR/SCENT
# REGULAR             64359833  1.386889e+08
# CLASSIC             23666894  5.146254e+07
# BARBECUE            20337720  3.911207e+07
# ORIGINAL            17851000  4.668455e+07
# SOUR CREAM & ONION  15021345  2.982388e+07

# %%
## 2009

# For this we will consider the most recent year 2011.

# Combine data for drugstores and grocery stores
frames = [store_data['year09drug'], store_data['year09groc']]
data_2009 = pd.concat(frames)

# %%
# Merge the store data with product category data
data_2009_with_cat = pd.merge(data_2009[['ITEM','UNITS','DOLLARS']], prod_cat_3[['ITEM','PRODUCT TYPE','PACKAGE','FLAVOR/SCENT']], how='left', on=['ITEM', 'ITEM'])

# %%
# Get the most popular product 
# Filtered out only required columns as using the entire table was causing the system to crash
# temp = data_2010_with_cat[['PRODUCT TYPE','PACKAGE','FLAVOR/SCENT','UNITS','DOLLARS']]
temp = data_2009_with_cat.copy()

# %%
temp.groupby(['PRODUCT TYPE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                    UNITS       DOLLARS
# PRODUCT TYPE
# POTATO CHIP    225818321  4.959843e+08
# TORTILLA CHIP  120490841  3.078093e+08
# RTE POPCORN    103041702  2.286662e+08
# PRETZEL         68392208  1.560690e+08
# CHEESE SNACK    43395504  8.579934e+07

# %%
# Now that we know that 'Potato Chip' is the most popular product, I wanted to understand if we see any preference in packaging
temp[temp['PRODUCT TYPE']=='POTATO CHIP'].groupby(['PACKAGE'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                           UNITS       DOLLARS
# PACKAGE
# BAG                   217485247  4.759658e+08
# BOX                     2715189  6.537386e+06
# BAG IN BOX              2562690  6.379855e+06
# BAG IN BAG               852028  2.341307e+06
# BAG IN BAG INDV WRAP     717269  1.618975e+06

# %%
# Knowing that 'Potato chip' in a bag is the most preferred product, I wanted to see if there is any preference for flavour
temp[(temp['PRODUCT TYPE']=='POTATO CHIP')&(temp['PACKAGE']=='BAG')].groupby(['FLAVOR/SCENT'])['UNITS','DOLLARS'].sum().sort(['UNITS','DOLLARS'],ascending = [0,0]).head(5)
# Out:
#                        UNITS       DOLLARS
# FLAVOR/SCENT
# REGULAR             63574109  1.367132e+08
# CLASSIC             24526637  5.550303e+07
# BARBECUE            20644738  4.068679e+07
# ORIGINAL            18093570  4.903277e+07
# SOUR CREAM & ONION  14588031  2.927428e+07
